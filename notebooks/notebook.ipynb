# %%
from pathlib import Path, PurePath
import pandas as pd
import os
import sys


current_dir = "/Users/alexgiving/Documents/PythonProjects/class_ml_lab1/"
sys.path.append(current_dir)
import src.config as cfg

# %%
train = pd.read_csv(os.path.join(current_dir, 'data/raw/train.csv'))
test  = pd.read_csv(os.path.join(current_dir, 'data/raw/test.csv'))

# %%
train
# Out:
#                 ID Пол                      Семья        Этнос Национальность  \
# 0    54-102-358-02   М  в браке в настоящее время  европейская        Русские
# 1    54-103-101-01   Ж                  в разводе  европейская        Русские
# 2    54-501-026-03   Ж  в браке в настоящее время  европейская        Русские
# 3    54-501-094-02   М  в браке в настоящее время  европейская        Русские
# 4    54-503-022-01   Ж  в браке в настоящее время  европейская        Русские
# ..             ...  ..                        ...          ...            ...
# 950  54-103-006-01   М  в браке в настоящее время  европейская        Русские
# 951  54-701-039-01   Ж             вдовец / вдова  европейская        Русские
# 952  54-002-014-01   Ж  в браке в настоящее время  европейская        Русские
# 953  54-501-022-01   Ж  в браке в настоящее время  европейская        Русские
# 954  54-702-016-01   М  в браке в настоящее время  европейская        Русские
#
# ...

# %%
print(cfg.TARGET_COLS)
print(cfg.ID_COL)
print(cfg.EDU_COL)
print(cfg.SEX_COL)
print(cfg.CAT_COLS)
print(cfg.OHE_COLS)
print(cfg.REAL_COLS)
# Out:
# ['Артериальная гипертензия', 'ОНМК', 'Стенокардия, ИБС, инфаркт миокарда', 'Сердечная недостаточность', 'Прочие заболевания сердца']
# ID
# Образование
# Пол
# ['Пол', 'Семья', 'Этнос', 'Национальность', 'Религия', 'Образование', 'Профессия', 'Статус Курения', 'Частота пасс кур', 'Алкоголь', 'Время засыпания', 'Время пробуждения']
# ['Вы работаете?', 'Выход на пенсию', 'Прекращение работы по болезни', 'Сахарный диабет', 'Гепатит', 'Онкология', 'Хроническое заболевание легких', 'Бронжиальная астма', 'Туберкулез легких ', 'ВИЧ/СПИД', 'Регулярный прим лекарственных средств', 'Травмы за год', 'Переломы', 'Пассивное курение', 'Сон после обеда', 'Спорт, клубы', 'Религия, клубы']
# ['Возраст курения', 'Сигарет в день', 'Возраст алког']

# %%
def set_idx(df: pd.DataFrame, idx_col: str) -> pd.DataFrame:
    df = df.set_index(idx_col)
    return df
    

train, test = train.set_index(cfg.ID_COL), test.set_index(cfg.ID_COL)
train, target = train.drop(cfg.TARGET_COLS, axis=1), train[cfg.TARGET_COLS]

# %%
def drop_unnecesary_id(df: pd.DataFrame) -> pd.DataFrame:
    if 'ID_y' in df.columns:
        df = df.drop('ID_y', axis=1)
    return df

train = drop_unnecesary_id(train)

# %% [markdown]
# ### Make a model

# %%
from sklearn.svm import LinearSVC
import sys


model = LinearSVC()

# %% [markdown]
# ### Training pipe

# %%
train.pipe(
    
)
